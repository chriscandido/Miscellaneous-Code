# %%
###############################################################################################
# PlanetScope Imagery Preprocessing                                                           #
# To automatically perform ToA and DOS correction on PlanetScope Imagery                      #
# image product name is generally composed of the following elements:                         #
# <acquisition date>_<acquisition time>_<satellite id>_<productLevel><bandProduct>.<extension>#
###############################################################################################

# %%
#import dependencies and set the working paths 
import rasterio
import shutil
import pandas
import numpy
import math
import glob
import sys
import os
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET

from osgeo import gdal
from osgeo.gdalconst import *


path = r"C:\Users\envisage\Desktop\LULC Mapping\laguna_planet_q1"
foldername = r"C:\Users\envisage\Desktop\LULC Mapping\Laguna"
gdal_merge_path = r"C:\Users\Rudy\AppData\Local\Programs\Python\Python36\GDAL-2.2.3"

#define xml abbreviations
ps="{http://schemas.planet.com/ps/v1/planet_product_metadata_geocorrected_level}"
eop="{http://earth.esa.int/eop}"
gml="{http://www.opengis.net/gml}"
opt="{http://earth.esa.int/opt}"

# %%
coeff = {}
for root, dirs, files in os.walk (path):
    for name in files:
        if name.endswith((".xml")) and not name.startswith(('.')):
            print ('xml file:', name)
        
            data = ET.parse(root + "/" + name)
            tags = data.getroot()
            
            coeff_temp = {name.split('_metadata')[0]:{'rc_b1': '', 'rc_b2': '', 'rc_b3': '', 'rc_b4': ''}}
            
            for member in tags.findall(gml+'resultOf'):
                for submember in member.findall(ps+'EarthObservationResult'):
                    for info in submember.findall(ps+'bandSpecificMetadata'):
                        band = info.find(ps+'bandNumber').text
                        rf = info.find(ps+'reflectanceCoefficient').text
                        
                        coeff_temp[name.split('_metadata')[0]]['rc_b'+band] = rf
            
            coeff.update(coeff_temp)
         
            #os.mkdir(r'C:/Users/Rudy/Desktop/KII/planet_order_125125/20151225_003546_1_0c74/%s'%name.split('_metadata')[0])
            tmpfolderName = foldername+'/%s'%name.split('_metadata')[0]
            print (tmpfolderName)
            
            for i in range (len(coeff)):
                for j in range (len(coeff[name.split('_metadata')[i]])):
                    print ('rc_b'+str(j+1)+': ', coeff[name.split('_metadata')[i]]['rc_b'+str(j+1)])  
                        
            image = root+"/"+name.split('_metadata')[0]+'.tif'
            raster = gdal.Open(image)
        
            if raster is None: 
                print ('Unable to Open Raster Dataset', raster)
        
            for b in range (raster.RasterCount + 1)[1::]:
                with rasterio.open(image) as src:
                    band = src.read(b)
                    band = band*float(coeff[name.split('_metadata')[0]]['rc_b%s'%b])
                    kwargs = src.meta 
                    kwargs.update(dtype=rasterio.float32, count=1)
                    with rasterio.open (tmpfolderName+'_'+str(b)+'.tiff', 'w', **kwargs) as dst:
                        dst.write_band(1, band.astype(rasterio.float32))
            
            outvrt = '/vsimem/stacked.vrt'
            outtif = foldername+'/%s'%name.split('_metadata')[0]+'_TOA.tif'
            
            merge_command_2 = sorted(glob.glob(foldername+"/*.tiff"))
            #print (merge_command_2)
            
            outds = gdal.BuildVRT(outvrt, merge_command_2, separate=True)
            outds = gdal.Translate(outtif, outds)
            
            #remove the genarated tif file 
            for b in range (raster.RasterCount + 1)[1::]:
                file = tmpfolderName+'_'+str(b)+'.tiff'
                if os.path.isfile(file):
                    os.remove(file)
                else:
                    print ("Error: %s file not found"%file)
                    
            del(coeff[name.split('_metadata')[0]])  
            

print ('Done')
# Out:
# xml file: 20170103_050728_0c76_3B_AnalyticMS_metadata.xml
# {'20170103_050728_0c76_3B_AnalyticMS': {'rc_b1': '2.0369393579e-05', 'rc_b2': '2.17661336798e-05', 'rc_b3': '2.42953012781e-05', 'rc_b4': '3.67509029687e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170103_050728_0c76_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.0369393579e-05
# 1
# rc_b2:  2.17661336798e-05
# 2
# rc_b3:  2.42953012781e-05
# 3
# rc_b4:  3.67509029687e-05
# xml file: 20170103_050729_0c76_3B_AnalyticMS_metadata.xml
# {'20170103_050729_0c76_3B_AnalyticMS': {'rc_b1': '2.03620279486e-05', 'rc_b2': '2.17582629843e-05', 'rc_b3': '2.42865160284e-05', 'rc_b4': '3.67376137381e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170103_050729_0c76_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.03620279486e-05
# 1
# rc_b2:  2.17582629843e-05
# 2
# rc_b3:  2.42865160284e-05
# 3
# rc_b4:  3.67376137381e-05
# xml file: 20170103_050730_0c76_3B_AnalyticMS_metadata.xml
# {'20170103_050730_0c76_3B_AnalyticMS': {'rc_b1': '2.03543347076e-05', 'rc_b2': '2.17500422136e-05', 'rc_b3': '2.42773400257e-05', 'rc_b4': '3.67237334252e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170103_050730_0c76_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.03543347076e-05
# 1
# rc_b2:  2.17500422136e-05
# 2
# rc_b3:  2.42773400257e-05
# 3
# rc_b4:  3.67237334252e-05
# xml file: 20170103_050731_0c76_3B_AnalyticMS_metadata.xml
# {'20170103_050731_0c76_3B_AnalyticMS': {'rc_b1': '2.03470332032e-05', 'rc_b2': '2.17422400412e-05', 'rc_b3': '2.42686312614e-05', 'rc_b4': '3.67105598923e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170103_050731_0c76_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.03470332032e-05
# 1
# rc_b2:  2.17422400412e-05
# 2
# rc_b3:  2.42686312614e-05
# 3
# rc_b4:  3.67105598923e-05
# xml file: 20170103_050732_1_0c76_3B_AnalyticMS_metadata.xml
# {'20170103_050732_1_0c76_3B_AnalyticMS': {'rc_b1': '2.03398092735e-05', 'rc_b2': '2.17345207628e-05', 'rc_b3': '2.42600150231e-05', 'rc_b4': '3.66975263211e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170103_050732_1_0c76_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.03398092735e-05
# 1
# rc_b2:  2.17345207628e-05
# 2
# rc_b3:  2.42600150231e-05
# 3
# rc_b4:  3.66975263211e-05
# xml file: 20170108_014024_0e19_3B_AnalyticMS_metadata.xml
# {'20170108_014024_0e19_3B_AnalyticMS': {'rc_b1': '2.46860044743e-05', 'rc_b2': '2.60773605036e-05', 'rc_b3': '2.91214233412e-05', 'rc_b4': '4.40164497128e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170108_014024_0e19_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.46860044743e-05
# 1
# rc_b2:  2.60773605036e-05
# 2
# rc_b3:  2.91214233412e-05
# 3
# rc_b4:  4.40164497128e-05
# xml file: 20170108_014025_0e19_3B_AnalyticMS_metadata.xml
# {'20170108_014025_0e19_3B_AnalyticMS': {'rc_b1': '2.46626989274e-05', 'rc_b2': '2.60527414063e-05', 'rc_b3': '2.9093930407e-05', 'rc_b4': '4.39748946919e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170108_014025_0e19_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.46626989274e-05
# 1
# rc_b2:  2.60527414063e-05
# 2
# rc_b3:  2.9093930407e-05
# 3
# rc_b4:  4.39748946919e-05
# xml file: 20170113_013948_0e19_3B_AnalyticMS_metadata.xml
# {'20170113_013948_0e19_3B_AnalyticMS': {'rc_b1': '2.44941743331e-05', 'rc_b2': '2.58747184052e-05', 'rc_b3': '2.88951264223e-05', 'rc_b4': '4.36744064399e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170113_013948_0e19_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.44941743331e-05
# 1
# rc_b2:  2.58747184052e-05
# 2
# rc_b3:  2.88951264223e-05
# 3
# rc_b4:  4.36744064399e-05
# xml file: 20170122_014101_0e20_3B_AnalyticMS_metadata.xml
# {'20170122_014101_0e20_3B_AnalyticMS': {'rc_b1': '2.47169622519e-05', 'rc_b2': '2.58572737013e-05', 'rc_b3': '2.89540076385e-05', 'rc_b4': '4.31386367977e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170122_014101_0e20_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.47169622519e-05
# 1
# rc_b2:  2.58572737013e-05
# 2
# rc_b3:  2.89540076385e-05
# 3
# rc_b4:  4.31386367977e-05
# xml file: 20170129_014201_0e3a_3B_AnalyticMS_metadata.xml
# {'20170129_014201_0e3a_3B_AnalyticMS': {'rc_b1': '2.37314431665e-05', 'rc_b2': '2.51063566239e-05', 'rc_b3': '2.80470517648e-05', 'rc_b4': '4.2603812258e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170129_014201_0e3a_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.37314431665e-05
# 1
# rc_b2:  2.51063566239e-05
# 2
# rc_b3:  2.80470517648e-05
# 3
# rc_b4:  4.2603812258e-05
# xml file: 20170131_014132_0e0f_3B_AnalyticMS_metadata.xml
# {'20170131_014132_0e0f_3B_AnalyticMS': {'rc_b1': '2.42119876625e-05', 'rc_b2': '2.53258340607e-05', 'rc_b3': '2.83925371346e-05', 'rc_b4': '4.15835090078e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170131_014132_0e0f_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.42119876625e-05
# 1
# rc_b2:  2.53258340607e-05
# 2
# rc_b3:  2.83925371346e-05
# 3
# rc_b4:  4.15835090078e-05
# xml file: 20170131_014133_0e0f_3B_AnalyticMS_metadata.xml
# {'20170131_014133_0e0f_3B_AnalyticMS': {'rc_b1': '2.419482222e-05', 'rc_b2': '2.53078789405e-05', 'rc_b3': '2.83724078305e-05', 'rc_b4': '4.15540277714e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170131_014133_0e0f_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.419482222e-05
# 1
# rc_b2:  2.53078789405e-05
# 2
# rc_b3:  2.83724078305e-05
# 3
# rc_b4:  4.15540277714e-05
# xml file: 20170131_014134_0e0f_3B_AnalyticMS_metadata.xml
# {'20170131_014134_0e0f_3B_AnalyticMS': {'rc_b1': '2.41777117426e-05', 'rc_b2': '2.5289981314e-05', 'rc_b3': '2.83523429819e-05', 'rc_b4': '4.15246409361e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170131_014134_0e0f_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.41777117426e-05
# 1
# rc_b2:  2.5289981314e-05
# 2
# rc_b3:  2.83523429819e-05
# 3
# rc_b4:  4.15246409361e-05
# xml file: 20170131_014135_0e0f_3B_AnalyticMS_metadata.xml
# {'20170131_014135_0e0f_3B_AnalyticMS': {'rc_b1': '2.41606608769e-05', 'rc_b2': '2.52721460416e-05', 'rc_b3': '2.83323480379e-05', 'rc_b4': '4.14953564826e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170131_014135_0e0f_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.41606608769e-05
# 1
# rc_b2:  2.52721460416e-05
# 2
# rc_b3:  2.83323480379e-05
# 3
# rc_b4:  4.14953564826e-05
# xml file: 20170131_014136_0e0f_3B_AnalyticMS_metadata.xml
# {'20170131_014136_0e0f_3B_AnalyticMS': {'rc_b1': '2.41436661539e-05', 'rc_b2': '2.52543694947e-05', 'rc_b3': '2.83124189304e-05', 'rc_b4': '4.14661684528e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170131_014136_0e0f_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.41436661539e-05
# 1
# rc_b2:  2.52543694947e-05
# 2
# rc_b3:  2.83124189304e-05
# 3
# rc_b4:  4.14661684528e-05
# xml file: 20170131_014138_0e0f_3B_AnalyticMS_metadata.xml
# {'20170131_014138_0e0f_3B_AnalyticMS': {'rc_b1': '2.41267305815e-05', 'rc_b2': '2.52366548195e-05', 'rc_b3': '2.82925591867e-05', 'rc_b4': '4.14370820127e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170131_014138_0e0f_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.41267305815e-05
# 1
# rc_b2:  2.52366548195e-05
# 2
# rc_b3:  2.82925591867e-05
# 3
# rc_b4:  4.14370820127e-05
# xml file: 20170223_083045_0c79_3B_AnalyticMS_metadata.xml
# {'20170223_083045_0c79_3B_AnalyticMS': {'rc_b1': '4.46669132349e-05', 'rc_b2': '4.77297471211e-05', 'rc_b3': '5.32758184477e-05', 'rc_b4': '8.05890164495e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170223_083045_0c79_3B_AnalyticMS
# 0
# 0
# rc_b1:  4.46669132349e-05
# 1
# rc_b2:  4.77297471211e-05
# 2
# rc_b3:  5.32758184477e-05
# 3
# rc_b4:  8.05890164495e-05
# xml file: 20170223_083046_0c79_3B_AnalyticMS_metadata.xml
# {'20170223_083046_0c79_3B_AnalyticMS': {'rc_b1': '4.470965198e-05', 'rc_b2': '4.77754164846e-05', 'rc_b3': '5.33267944713e-05', 'rc_b4': '8.0666126623e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170223_083046_0c79_3B_AnalyticMS
# 0
# 0
# rc_b1:  4.470965198e-05
# 1
# rc_b2:  4.77754164846e-05
# 2
# rc_b3:  5.33267944713e-05
# 3
# rc_b4:  8.0666126623e-05
# xml file: 20170225_014142_0e1f_3B_AnalyticMS_metadata.xml
# {'20170225_014142_0e1f_3B_AnalyticMS': {'rc_b1': '2.22756467297e-05', 'rc_b2': '2.33251130686e-05', 'rc_b3': '2.61665851837e-05', 'rc_b4': '3.88307144538e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170225_014142_0e1f_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.22756467297e-05
# 1
# rc_b2:  2.33251130686e-05
# 2
# rc_b3:  2.61665851837e-05
# 3
# rc_b4:  3.88307144538e-05
# xml file: 20170225_014143_0e1f_3B_AnalyticMS_metadata.xml
# {'20170225_014143_0e1f_3B_AnalyticMS': {'rc_b1': '2.22656199733e-05', 'rc_b2': '2.33146139245e-05', 'rc_b3': '2.61548070308e-05', 'rc_b4': '3.88132358991e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170225_014143_0e1f_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.22656199733e-05
# 1
# rc_b2:  2.33146139245e-05
# 2
# rc_b3:  2.61548070308e-05
# 3
# rc_b4:  3.88132358991e-05
# xml file: 20170225_014144_0e1f_3B_AnalyticMS_metadata.xml
# {'20170225_014144_0e1f_3B_AnalyticMS': {'rc_b1': '2.2255636069e-05', 'rc_b2': '2.33041596513e-05', 'rc_b3': '2.61430792149e-05', 'rc_b4': '3.87958320435e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170225_014144_0e1f_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.2255636069e-05
# 1
# rc_b2:  2.33041596513e-05
# 2
# rc_b3:  2.61430792149e-05
# 3
# rc_b4:  3.87958320435e-05
# xml file: 20170225_014145_0e1f_3B_AnalyticMS_metadata.xml
# {'20170225_014145_0e1f_3B_AnalyticMS': {'rc_b1': '2.22456948723e-05', 'rc_b2': '2.32937500978e-05', 'rc_b3': '2.61314015666e-05', 'rc_b4': '3.87785026355e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170225_014145_0e1f_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.22456948723e-05
# 1
# rc_b2:  2.32937500978e-05
# 2
# rc_b3:  2.61314015666e-05
# 3
# rc_b4:  3.87785026355e-05
# xml file: 20170225_014147_0e1f_3B_AnalyticMS_metadata.xml
# {'20170225_014147_0e1f_3B_AnalyticMS': {'rc_b1': '2.22357924971e-05', 'rc_b2': '2.32833811947e-05', 'rc_b3': '2.61197695206e-05', 'rc_b4': '3.87612409007e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170225_014147_0e1f_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.22357924971e-05
# 1
# rc_b2:  2.32833811947e-05
# 2
# rc_b3:  2.61197695206e-05
# 3
# rc_b4:  3.87612409007e-05
# xml file: 20170225_014148_0e1f_3B_AnalyticMS_metadata.xml
# {'20170225_014148_0e1f_3B_AnalyticMS': {'rc_b1': '2.22259350452e-05', 'rc_b2': '2.32730593314e-05', 'rc_b3': '2.6108190245e-05', 'rc_b4': '3.8744057476e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170225_014148_0e1f_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.22259350452e-05
# 1
# rc_b2:  2.32730593314e-05
# 2
# rc_b3:  2.6108190245e-05
# 3
# rc_b4:  3.8744057476e-05
# xml file: 20170225_014149_0e1f_3B_AnalyticMS_metadata.xml
# {'20170225_014149_0e1f_3B_AnalyticMS': {'rc_b1': '2.2215471728e-05', 'rc_b2': '2.32621030588e-05', 'rc_b3': '2.60958992761e-05', 'rc_b4': '3.8725817912e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170225_014149_0e1f_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.2215471728e-05
# 1
# rc_b2:  2.32621030588e-05
# 2
# rc_b3:  2.60958992761e-05
# 3
# rc_b4:  3.8725817912e-05
# xml file: 20170301_064437_0c54_3B_AnalyticMS_metadata.xml
# {'20170301_064437_0c54_3B_AnalyticMS': {'rc_b1': '2.18022416458e-05', 'rc_b2': '2.3385725708e-05', 'rc_b3': '2.58940304479e-05', 'rc_b4': '3.96638419769e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170301_064437_0c54_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.18022416458e-05
# 1
# rc_b2:  2.3385725708e-05
# 2
# rc_b3:  2.58940304479e-05
# 3
# rc_b4:  3.96638419769e-05
# xml file: 20170301_064438_0c54_3B_AnalyticMS_metadata.xml
# {'20170301_064438_0c54_3B_AnalyticMS': {'rc_b1': '2.18067058077e-05', 'rc_b2': '2.33905140994e-05', 'rc_b3': '2.58993324323e-05', 'rc_b4': '3.96719634268e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170301_064438_0c54_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.18067058077e-05
# 1
# rc_b2:  2.33905140994e-05
# 2
# rc_b3:  2.58993324323e-05
# 3
# rc_b4:  3.96719634268e-05
# xml file: 20170301_064440_0c54_3B_AnalyticMS_metadata.xml
# {'20170301_064440_0c54_3B_AnalyticMS': {'rc_b1': '2.18157038161e-05', 'rc_b2': '2.34001656279e-05', 'rc_b3': '2.59100191638e-05', 'rc_b4': '3.96883331005e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170301_064440_0c54_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.18157038161e-05
# 1
# rc_b2:  2.34001656279e-05
# 2
# rc_b3:  2.59100191638e-05
# 3
# rc_b4:  3.96883331005e-05
# xml file: 20170301_064440_1_0c54_3B_AnalyticMS_metadata.xml
# {'20170301_064440_1_0c54_3B_AnalyticMS': {'rc_b1': '2.18202339067e-05', 'rc_b2': '2.34050247363e-05', 'rc_b3': '2.59153994501e-05', 'rc_b4': '3.96965744914e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170301_064440_1_0c54_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.18202339067e-05
# 1
# rc_b2:  2.34050247363e-05
# 2
# rc_b3:  2.59153994501e-05
# 3
# rc_b4:  3.96965744914e-05
# xml file: 20170301_064442_0c54_3B_AnalyticMS_metadata.xml
# {'20170301_064442_0c54_3B_AnalyticMS': {'rc_b1': '2.18293615631e-05', 'rc_b2': '2.3414815329e-05', 'rc_b3': '2.59262401617e-05', 'rc_b4': '3.9713180028e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170301_064442_0c54_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.18293615631e-05
# 1
# rc_b2:  2.3414815329e-05
# 2
# rc_b3:  2.59262401617e-05
# 3
# rc_b4:  3.9713180028e-05
# xml file: 20170308_013959_0e19_3B_AnalyticMS_metadata.xml
# {'20170308_013959_0e19_3B_AnalyticMS': {'rc_b1': '2.10732747447e-05', 'rc_b2': '2.22610095968e-05', 'rc_b3': '2.4859582103e-05', 'rc_b4': '3.75747618067e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170308_013959_0e19_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.10732747447e-05
# 1
# rc_b2:  2.22610095968e-05
# 2
# rc_b3:  2.4859582103e-05
# 3
# rc_b4:  3.75747618067e-05
# xml file: 20170308_014000_0e19_3B_AnalyticMS_metadata.xml
# {'20170308_014000_0e19_3B_AnalyticMS': {'rc_b1': '2.10665165664e-05', 'rc_b2': '2.22538705131e-05', 'rc_b3': '2.48516096597e-05', 'rc_b4': '3.7562711618e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170308_014000_0e19_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.10665165664e-05
# 1
# rc_b2:  2.22538705131e-05
# 2
# rc_b3:  2.48516096597e-05
# 3
# rc_b4:  3.7562711618e-05
# xml file: 20170308_014001_0e19_3B_AnalyticMS_metadata.xml
# {'20170308_014001_0e19_3B_AnalyticMS': {'rc_b1': '2.10597958367e-05', 'rc_b2': '2.22467709887e-05', 'rc_b3': '2.48436813935e-05', 'rc_b4': '3.7550728202e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170308_014001_0e19_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.10597958367e-05
# 1
# rc_b2:  2.22467709887e-05
# 2
# rc_b3:  2.48436813935e-05
# 3
# rc_b4:  3.7550728202e-05
# xml file: 20170309_014324_0e3a_3B_AnalyticMS_metadata.xml
# {'20170309_014324_0e3a_3B_AnalyticMS': {'rc_b1': '2.09036382484e-05', 'rc_b2': '2.21147189794e-05', 'rc_b3': '2.47050050818e-05', 'rc_b4': '3.75272027578e-05'}}
# C:\Users\envisage\Desktop\LULC Mapping\Laguna/20170309_014324_0e3a_3B_AnalyticMS
# 0
# 0
# rc_b1:  2.09036382484e-05
# 1
# rc_b2:  2.21147189794e-05
# 2
# rc_b3:  2.47050050818e-05
# 3
# rc_b4:  3.75272027578e-05
# Done

# %%
##########################################################################
#Dark Object Subtraction 

folderpath = r"C:\Users\envisage\Desktop\LULC Mapping\Laguna"
foldername_DOS = r"C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS"

for root, dirs, files in os.walk (folderpath):
    for name in files:
        if name.endswith(("_TOA.tif")):     
            #os.mkdir(r'C:/Users/Rudy/Desktop/KII/planet_order_125125/20151225_003546_1_0c74/%s'%name.split('_metadata')[0])
            tmpfolderName = foldername_DOS +'/%s'%name.split('.tif')[0]
            
            ras = root+"/"+name
            ds = gdal.Open(folderpath+'/%s'%name)
        
            if ds is None:
                print ('Unable to Open Raster Dataset', ds)
            
        
            for b in range (ds.RasterCount + 1)[1::]:
                raster_band = ds.GetRasterBand(b)
                stat = raster_band.GetStatistics(True, True)
                b_min = stat[0]
                b_max = stat[1]
                with rasterio.open(ras) as src:
                    band = src.read(b, masked=True)
                    band = band - float(b_min)
                    kwargs = src.meta 
                    kwargs.update(dtype=rasterio.float32, count=1)
                    with rasterio.open (tmpfolderName+'_'+str(b)+'.tiff', 'w', **kwargs) as dst:
                        dst.write_band(1, band.astype(rasterio.float32))
            
            outvrt = '/vsimem/stacked.vrt'
            outtif = foldername_DOS+'/%s'%name.split('.tif')[0]+'_DOS.tif'
            print (outtif)
            
            merge_command_2 = sorted(glob.glob(foldername_DOS+"/*.tiff"))
            #print (merge_command_2)
            
            outds = gdal.BuildVRT(outvrt, merge_command_2, separate=True)
            outds = gdal.Translate(outtif, outds)
            
            #remove the genarated tif file 
            for b in range (raster.RasterCount + 1)[1::]:
                file = tmpfolderName+'_'+str(b)+'.tiff'
                if os.path.isfile(file):
                    os.remove(file)
                else:
                    print ("Error: %s file not found"%file)
                    
print ('Done')
# Out:
# Tiff file: 20170103_050728_0c76_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170103_050728_0c76_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170103_050728_0c76_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170103_050729_0c76_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170103_050729_0c76_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170103_050729_0c76_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170103_050730_0c76_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170103_050730_0c76_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170103_050730_0c76_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170103_050731_0c76_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170103_050731_0c76_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170103_050731_0c76_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170103_050732_1_0c76_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170103_050732_1_0c76_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170103_050732_1_0c76_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170108_014024_0e19_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170108_014024_0e19_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170108_014024_0e19_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170108_014025_0e19_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170108_014025_0e19_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170108_014025_0e19_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170113_013948_0e19_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170113_013948_0e19_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170113_013948_0e19_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170122_014101_0e20_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170122_014101_0e20_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170122_014101_0e20_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170129_014201_0e3a_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170129_014201_0e3a_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170129_014201_0e3a_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170131_014132_0e0f_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170131_014132_0e0f_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170131_014132_0e0f_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170131_014133_0e0f_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170131_014133_0e0f_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170131_014133_0e0f_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170131_014134_0e0f_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170131_014134_0e0f_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170131_014134_0e0f_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170131_014135_0e0f_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170131_014135_0e0f_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170131_014135_0e0f_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170131_014136_0e0f_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170131_014136_0e0f_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170131_014136_0e0f_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170131_014138_0e0f_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170131_014138_0e0f_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170131_014138_0e0f_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170223_083045_0c79_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170223_083045_0c79_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170223_083045_0c79_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170223_083046_0c79_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170223_083046_0c79_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170223_083046_0c79_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170225_014142_0e1f_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170225_014142_0e1f_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170225_014142_0e1f_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170225_014143_0e1f_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170225_014143_0e1f_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170225_014143_0e1f_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170225_014144_0e1f_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170225_014144_0e1f_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170225_014144_0e1f_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170225_014145_0e1f_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170225_014145_0e1f_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170225_014145_0e1f_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170225_014147_0e1f_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170225_014147_0e1f_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170225_014147_0e1f_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170225_014148_0e1f_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170225_014148_0e1f_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170225_014148_0e1f_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170225_014149_0e1f_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170225_014149_0e1f_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170225_014149_0e1f_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170301_064437_0c54_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170301_064437_0c54_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170301_064437_0c54_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170301_064438_0c54_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170301_064438_0c54_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170301_064438_0c54_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170301_064440_0c54_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170301_064440_0c54_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170301_064440_0c54_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170301_064440_1_0c54_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170301_064440_1_0c54_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170301_064440_1_0c54_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170301_064442_0c54_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170301_064442_0c54_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170301_064442_0c54_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170308_013959_0e19_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170308_013959_0e19_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170308_013959_0e19_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170308_014000_0e19_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170308_014000_0e19_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170308_014000_0e19_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170308_014001_0e19_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170308_014001_0e19_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170308_014001_0e19_3B_AnalyticMS_TOA_DOS.tif
# Tiff file: 20170309_014324_0e3a_3B_AnalyticMS_TOA.tif
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170309_014324_0e3a_3B_AnalyticMS_TOA
# C:\Users\envisage\Desktop\LULC Mapping\Laguna_DOS/20170309_014324_0e3a_3B_AnalyticMS_TOA_DOS.tif
# Done

# %%
##################################################################
#Calculate Indices

for item in os.listdir(path):
    if item.endswith(("_DOS.tif")):
        with rasterio.open(path+'/%s'%item) as src:
            b1 = src.read(1)
        with rasterio.open(path+'/%s'%item) as src:
            b2 = src.read(2)
        with rasterio.open(path+'/%s'%item) as src:
            b3 = src.read(3)
        with rasterio.open(path+'/%s'%item) as src:
            b4 = src.read(4)
            
        numpy.seterr(divide='ignore', invalid='ignore')
        
        ndvi = (b4.astype(float) - b3.astype(float))/(b4 + b3)
        ndwi = (b3.astype(float) - b4.astype(float))/(b3 + b4)
        savi = ((1+0.5)*(b4.astype(float) - b3.astype(float)))/(b4 + b3 + 0.5)
        redi = (b3.astype(float) - b2.astype(float))/(b3 + b2)
        brti = (b3.astype(float) + b2.astype(float) + b1.astype(float))/3
        
        kwargs = src.meta
        kwargs.update(dtype=rasterio.float32, count=1)
        
        with rasterio.open(path+'\%s'%item.split('.tif')[0]+'_ndvi.tif', 'w', **kwargs) as dst:
            dst.write_band(1, ndvi.astype(rasterio.float32))
            
        with rasterio.open(path+'\%s'%item.split('.tif')[0]+'_ndwi.tif', 'w', **kwargs) as dst:
            dst.write_band(1, ndwi.astype(rasterio.float32))
            
        with rasterio.open(path+'\%s'%item.split('.tif')[0]+'_savi.tif', 'w', **kwargs) as dst:
            dst.write_band(1, savi.astype(rasterio.float32))
        
        with rasterio.open(path+'\%s'%item.split('.tif')[0]+'_redi.tif', 'w', **kwargs) as dst:
            dst.write_band(1, redi.astype(rasterio.float32))
        
        with rasterio.open(path+'\%s'%item.split('.tif')[0]+'_brti.tif', 'w', **kwargs) as dst:
            dst.write_band(1, brti.astype(rasterio.float32))
        
        #showImage(ndvi,'NDVI')

print ('Done')
# Out:
# Done
